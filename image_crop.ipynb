# %%
# 진행률을 시각화 하는데 필요한 라이브러리 설치
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
import json
import glob
import os
import matplotlib.pyplot as plt
import pandas as pd
import time
from tqdm import tqdm

# %%
# 이미지 크롭 작업 할 감정 설정
emotion = "sadness"
# json 파일이 저장되어 있는 폴더 경로 설정
path_json = "/content/drive/MyDrive/Colab_Notebooks/WASSUP/project_3/data/label/test/"
# 이미지 파일이 저장되어 있는 폴더 경로 설정
path_imgs = "/content/drive/MyDrive/Colab_Notebooks/WASSUP/project_3/data/img/test/"
# crop한 이미지 저장할 경로 설정
path_crop = "/content/drive/MyDrive/Colab_Notebooks/WASSUP/project_3/data/img/test/processed/"

# %%
# 설정한 감정에 해당하는 json파일을 읽어옵니다.
# with open (path_json + "train_"+emotion+".json", "r", encoding='euc-kr') as f:
with open (path_json + "test_"+emotion+".json", "r", encoding='euc-kr') as f:
    data = json.load(f)

# %%
# 이미지 크롭 후 저장
for i in tqdm(range(len(data)), desc='이미지 crop 진행률'):
    img_name=data[i]['filename']
    img_path=path_imgs+emotion+"/"+img_name
    crop_img_path=path_crop+emotion+"/"+img_name
    try:
        img=cv2.imread(img_path)
        min_X=int(data[i]['annot_A']["boxes"]["minX"])
        max_X=int(data[i]['annot_A']["boxes"]["maxX"])
        min_Y=int(data[i]['annot_A']["boxes"]["minY"])
        max_Y=int(data[i]['annot_A']["boxes"]["maxY"])
        cropped_img = img[min_Y:max_Y, min_X:max_X]
        cv2.imwrite(crop_img_path, cropped_img)
    except:
        print()
        print(img_path)
        # print(img_name+"가 존재하지 않습니다.")
        pass
# Out:
# 이미지 crop 진행률: 100%|██████████| 284/284 [01:00<00:00,  4.67it/s]
